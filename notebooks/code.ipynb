# %% [markdown]
# # Classification ignition point
#
# This project is a classification problem
#
# It is to determine whether a point has a probability to be an ignition point for wildfire. The ignition point is where the wildfire starts.

# %%
import pandas as pd

# %% [markdown]
# # Download data

# %%
dataframe_path =  "../data/classification_dataframe/dataset.csv"

# %%
df = pd.read_csv(dataframe_path, index_col=0)
df.head()
# Out:
#          Date  distance_fire_stations  distance_rivers  distance_roads  \
# 0  2015-11-19            13287.682266      7211.102551     1250.000000
# 1  2003-02-17             8721.381771      2358.495283      250.000000
# 2  2012-02-26            10796.411441         0.000000     2015.564437
# 3  2004-11-10             8253.787010       559.016994        0.000000
# 4  2003-03-19             9905.806378         0.000000     1903.943276
#
#    distance_powerlines  cropland  forest_deciduous_broad  \
# 0         30196.233209       0.0                     0.0
# 1         13768.169813       0.0                     0.0
# 2          6254.998002       0.0                     0.0
# 3         37350.535471       0.0                     0.0
# 4          6427.480066       0.0                     0.0
#
#    forest_deciduous_needle  forest_evergreen_broad  forest_evergreen_needle  \
# 0                      0.0                1.000000                      0.0
# 1                      0.0                0.416667                      0.0
# 2                      0.0                0.666667                      0.0
# 3                      0.0                0.000000                      0.0
# 4                      0.0                0.750000                      0.0
#
#    ...  avg_wind_angle  avg_rel_hum  avg_soil  sum_prec    forest  \
# 0  ...      225.773605    56.837185  0.297854  0.360376  1.000000
# 1  ...      209.708847    61.120739  0.264534  0.020176  0.833333
# 2  ...       76.341278    63.017559  0.208871  0.025395  1.000000
# 3  ...       68.557823    64.673866  0.156506  0.000000  0.000000
# 4  ...      316.951508    56.103680  0.208831  0.119717  0.916667
#
#    vegetation_class  Year  max_max_temp  yearly_avg_temp  ignition
# 0            forest  2015     62.552337        14.994683         1
# 1            forest  2003     60.787457        15.053698         1
# 2            forest  2012     63.420256        15.001883         1
# 3           wetland  2004     60.394119        14.850611         1
# 4            forest  2003     69.570496              NaN         1
#
# [5 rows x 42 columns]

# %% [markdown]
# # Data exploration

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
data = df.copy() # Avoid modifying the original dataset directly
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22035 entries, 0 to 22034
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     22035 non-null  object
#  1   distance_fire_stations   22030 non-null  float64
#  2   distance_rivers          22030 non-null  float64
#  3   distance_roads           22030 non-null  float64
#  4   distance_powerlines      22030 non-null  float64
#  5   cropland                 22030 non-null  float64
#  6   forest_deciduous_broad   22030 non-null  float64
#  7   forest_deciduous_needle  22030 non-null  float64
#  8   forest_evergreen_broad   22030 non-null  float64
#  9   forest_evergreen_needle  22030 non-null  float64
#  10  forest_mixed             22030 non-null  float64
#  11  forest_unknown           22030 non-null  float64
#  12  herbaceous_vegetation    22030 non-null  float64
#  13  moss_lichen              22030 non-null  float64
#  14  shrubland                22030 non-null  float64
#  15  sprarse_vegetation       22030 non-null  float64
#  16  urban                    22030 non-null  float64
#  17  water                    22030 non-null  float64
#  18  wetland                  22030 non-null  float64
#  19  aspect                   22035 non-null  float64
#  20  elevation                22035 non-null  float64
#  21  pop_dens                 22035 non-null  float64
#  22  slope                    22035 non-null  float64
#  23  anom_max_temp            22035 non-null  float64
#  24  anom_max_wind_vel        22035 non-null  float64
#  25  anom_avg_temp            22035 non-null  float64
#  26  anom_avg_rel_hum         22035 non-null  float64
#  27  anom_avg_soil            22035 non-null  float64
#  28  anom_sum_prec            22035 non-null  float64
#  29  max_temp                 22035 non-null  float64
#  30  max_wind_vel             22035 non-null  float64
#  31  avg_temp                 22035 non-null  float64
#  32  avg_wind_angle           22035 non-null  float64
#  33  avg_rel_hum              22035 non-null  float64
#  34  avg_soil                 22035 non-null  float64
#  35  sum_prec                 22035 non-null  float64
#  36  forest                   22035 non-null  float64
#  37  vegetation_class         22003 non-null  object
#  38  Year                     22035 non-null  int64
#  39  max_max_temp             22035 non-null  float64
#  40  yearly_avg_temp          15204 non-null  float64
#  41  ignition                 22035 non-null  int64
# dtypes: float64(38), int64(2), object(2)
# memory usage: 7.2+ MB

# %% [markdown]
# - 42 columns for 220235 rows
# - Most of the columns are numeric
# - There is a patern of 5 missing values for vegetation (cropland to wetland) class and distances columns
# - yearly_avg_temp got way more NA values than the others

# %% [markdown]
# ## Treating NAs

# %%
(data.isna().sum().sort_values(ascending=False)/len(data)) * 100
# Out:
# yearly_avg_temp            31.000681
# vegetation_class            0.145224
# forest_deciduous_broad      0.022691
# distance_roads              0.022691
# distance_powerlines         0.022691
# cropland                    0.022691
# forest_evergreen_broad      0.022691
# forest_deciduous_needle     0.022691
# distance_fire_stations      0.022691
# distance_rivers             0.022691
# wetland                     0.022691
# forest_evergreen_needle     0.022691
# forest_mixed                0.022691
# forest_unknown              0.022691
# shrubland                   0.022691
# sprarse_vegetation          0.022691
# herbaceous_vegetation       0.022691
# moss_lichen                 0.022691
# urban                       0.022691
# water                       0.022691
# Date                        0.000000
# aspect                      0.000000
# slope                       0.000000
# anom_max_temp               0.000000
# elevation                   0.000000
# pop_dens                    0.000000
# anom_avg_temp               0.000000
# anom_max_wind_vel           0.000000
# anom_avg_rel_hum            0.000000
# anom_avg_soil               0.000000
# max_wind_vel                0.000000
# avg_temp                    0.000000
# anom_sum_prec               0.000000
# max_temp                    0.000000
# avg_rel_hum                 0.000000
# avg_wind_angle              0.000000
# sum_prec                    0.000000
# avg_soil                    0.000000
# forest                      0.000000
# Year                        0.000000
# max_max_temp                0.000000
# ignition                    0.000000
# dtype: float64

# %% [markdown]
# We start by investigate in the columns with a 5 NAs patern

# %%
five_na_col = (data.isna().sum().sort_values(ascending=False).iloc[2:20].index) # Getting the right columns
data.loc[data[five_na_col].isna().any(axis=1)] # Looking for rows with at least one NA value on those columns
# Out:
#              Date  distance_fire_stations  distance_rivers  distance_roads  \
# 8031   2002-01-12                     NaN              NaN             NaN
# 10398  2017-11-23                     NaN              NaN             NaN
# 14704  2016-12-04                     NaN              NaN             NaN
# 17444  2003-11-09                     NaN              NaN             NaN
# 20679  2005-06-30                     NaN              NaN             NaN
#
#        distance_powerlines  cropland  forest_deciduous_broad  \
# 8031                   NaN       NaN                     NaN
# 10398                  NaN       NaN                     NaN
# 14704                  NaN       NaN                     NaN
# 17444                  NaN       NaN                     NaN
# 20679                  NaN       NaN                     NaN
#
#        forest_deciduous_needle  forest_evergreen_broad  \
# 8031                       NaN                     NaN
# 10398                      NaN                     NaN
# 14704                      NaN                     NaN
# 17444                      NaN                     NaN
# 20679                      NaN                     NaN
#
#        forest_evergreen_needle  forest_mixed  forest_unknown  \
# 8031                       NaN           NaN             NaN
# 10398                      NaN           NaN             NaN
# 14704                      NaN           NaN             NaN
# 17444                      NaN           NaN             NaN
# 20679                      NaN           NaN             NaN
#
#        herbaceous_vegetation  moss_lichen  shrubland  sprarse_vegetation  \
# 8031                     NaN          NaN        NaN                 NaN
# 10398                    NaN          NaN        NaN                 NaN
# 14704                    NaN          NaN        NaN                 NaN
# 17444                    NaN          NaN        NaN                 NaN
# 20679                    NaN          NaN        NaN                 NaN
#
#        urban  water  wetland  aspect  elevation  pop_dens  slope  \
# 8031     NaN    NaN      NaN   180.0     -100.0       0.0    0.0
# 10398    NaN    NaN      NaN   180.0     -100.0       0.0    0.0
# 14704    NaN    NaN      NaN   180.0     -100.0       0.0    0.0
# 17444    NaN    NaN      NaN   180.0     -100.0       0.0    0.0
# 20679    NaN    NaN      NaN   180.0     -100.0       0.0    0.0
#
#        anom_max_temp  anom_max_wind_vel  anom_avg_temp  anom_avg_rel_hum  \
# 8031        3.050584           1.984823       2.600509          1.564607
# 10398       0.514747          -1.094081       0.296738          0.727473
# 14704       1.103007           7.155092       3.575976          3.085598
# 17444       4.784193           0.246209       3.965116          4.515396
# 20679      -1.015329           1.741244       1.452464          4.740787
#
#        anom_avg_soil  anom_sum_prec   max_temp  max_wind_vel    avg_temp  \
# 8031       -2.208324      -1.448593  16.505491      8.304798    9.224956
# 10398       0.379440      -0.016864  16.816555      6.190253  282.968863
# 14704       0.708121      -0.777676  16.565540      8.653773  284.352420
# 17444      -0.379844      -0.520869  15.144913      6.177687    9.987872
# 20679       1.613138       0.014350  15.958652      5.799219   10.151059
#
#        avg_wind_angle  avg_rel_hum  avg_soil  sum_prec  forest  \
# 8031       136.641388    71.991280  0.115327       0.0     0.0
# 10398      157.834579    71.008575  0.251052       0.0     0.0
# 14704      280.659943    78.968040  0.307418       0.0     0.0
# 17444      205.237061    80.847252  0.280676       0.0     0.0
# 20679      130.377090    78.182716  0.236421       0.0     0.0
#
#       vegetation_class  Year  max_max_temp  yearly_avg_temp  ignition
# 8031               NaN  2002     61.709884        14.995481         0
# 10398              NaN  2017     62.269799        15.037558         0
# 14704              NaN  2016     61.817973        15.052976         0
# 17444              NaN  2003     59.260843        15.037933         0
# 20679              NaN  2005     60.725573        14.815469         0

# %% [markdown]
# We clearly identify that for the "five NA's" columns, the five missings values are one the same rows.
# So I decide to remove these 5 rows from the data set

# %%
data = data.loc[~(data[five_na_col].isna().any(axis=1))] #removing the 5 rows

# %% [markdown]
# Let's look at the the column vegetation_class

# %%
data["vegetation_class"].value_counts()
# Out:
# vegetation_class
# forest                     9124
# water                      8108
# herbaceous_vegetation      3850
# Forestt                     549
# wetland                     224
# urban                        81
# shrubland                    66
# $herb$aceous_vegetation       1
# Name: count, dtype: int64

# %% [markdown]
# - misswritten input : $herb$aceous_vegetation and Forestt
# - cropland  and sparse_vegetation are missing

# %%
# correcting herbaceous
data.loc[data["vegetation_class"] == '$herb$aceous_vegetation', ["vegetation_class"]] = "herbaceous_vegetation"

# correcting forest
data.loc[data["vegetation_class"] == "Forestt" , ["vegetation_class"]] = "forest"

# %% [markdown]
# Now we should complete the column vegetation_class

# %%
vegetation_col =  ['cropland','herbaceous_vegetation', 'moss_lichen', 'shrubland',
                   'sprarse_vegetation', 'urban', 'water', 'wetland' ,
                   'forest', "vegetation_class"]

forest_type = [ 'forest_deciduous_needle', 'forest_evergreen_broad', 'forest_deciduous_broad',
               'forest_evergreen_needle', 'forest_mixed', 'forest_unknown']

data.loc[data["vegetation_class"].isna(),vegetation_col]
# Out:
#        cropland  herbaceous_vegetation  moss_lichen  shrubland  \
# 3360   1.000000               0.000000          0.0        0.0
# 3734   1.000000               0.000000          0.0        0.0
# 5913   0.916667               0.083333          0.0        0.0
# 6209   1.000000               0.000000          0.0        0.0
# 6530   1.000000               0.000000          0.0        0.0
# 6784   1.000000               0.000000          0.0        0.0
# 7150   0.916667               0.083333          0.0        0.0
# 7916   0.750000               0.083333          0.0        0.0
# 8572   1.000000               0.000000          0.0        0.0
# 8833   1.000000               0.000000          0.0        0.0
# 9177   1.000000               0.000000          0.0        0.0
# 10140  0.916667               0.083333          0.0        0.0
# 10674  1.000000               0.000000          0.0        0.0
# 10802  1.000000               0.000000          0.0        0.0
# 11911  0.916667               0.083333          0.0        0.0
# 12131  0.916667               0.083333          0.0        0.0
# 13105  1.000000               0.000000          0.0        0.0
# 13580  1.000000               0.000000          0.0        0.0
# 14154  1.000000               0.000000          0.0        0.0
# 14429  0.916667               0.000000          0.0        0.0
# 15227  1.000000               0.000000          0.0        0.0
# 16790  1.000000               0.000000          0.0        0.0
# 18318  1.000000               0.000000          0.0        0.0
# 18646  1.000000               0.000000          0.0        0.0
# 19565  1.000000               0.000000          0.0        0.0
# 20998  0.916667               0.083333          0.0        0.0
# 21045  1.000000               0.000000          0.0        0.0
#
#        sprarse_vegetation     urban  water  wetland    forest vegetation_class
# 3360                  0.0  0.000000    0.0      0.0  0.000000              NaN
# 3734                  0.0  0.000000    0.0      0.0  0.000000              NaN
# 5913                  0.0  0.000000    0.0      0.0  0.000000              NaN
# 6209                  0.0  0.000000    0.0      0.0  0.000000              NaN
# 6530                  0.0  0.000000    0.0      0.0  0.000000              NaN
# 6784                  0.0  0.000000    0.0      0.0  0.000000              NaN
# 7150                  0.0  0.000000    0.0      0.0  0.000000              NaN
# 7916                  0.0  0.083333    0.0      0.0  0.083333              NaN
# 8572                  0.0  0.000000    0.0      0.0  0.000000              NaN
# 8833                  0.0  0.000000    0.0      0.0  0.000000              NaN
# 9177                  0.0  0.000000    0.0      0.0  0.000000              NaN
# 10140                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 10674                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 10802                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 11911                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 12131                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 13105                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 13580                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 14154                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 14429                 0.0  0.000000    0.0      0.0  0.083333              NaN
# 15227                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 16790                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 18318                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 18646                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 19565                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 20998                 0.0  0.000000    0.0      0.0  0.000000              NaN
# 21045                 0.0  0.000000    0.0      0.0  0.000000              NaN

# %% [markdown]
# Cropland is missing when it's the main vegetation class so let's complete the df

# %%
data.loc[data["vegetation_class"].isna(),"vegetation_class"] = "cropland"

# %% [markdown]
# Investsigate on sparse vegetation

# %%
sns.histplot(data= data["sprarse_vegetation"], bins= 30)
plt.show()

# %% [markdown]
# The column is full of 0 so we can get ride of it.
#
# Might look at the others

# %%
n_cols = len(vegetation_col[:-1]+ forest_type)
cols_per_row = 3
rows = int(np.ceil(n_cols / cols_per_row))

fig, ax = plt.subplots(rows, cols_per_row, figsize=(16, 4 * rows))
ax = ax.flatten()
for i, col in enumerate(vegetation_col[:-1]+ forest_type) : # Dropping the vegetation_class column for those histograms
    sns.histplot(data= data[col], bins= 30, ax=ax[i], stat='proportion')
    ax[i].set_ylim(0,1.1)

# remove empty axes if the number of columns is not a multiple of 3
for j in range(i + 1, len(ax)):
    fig.delaxes(ax[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# We see for each vegetation class, most frequently, the proportion of the class is close to 0. So, I can assume that if i delete these columns and only keep the column called "vegetation_class", I won't lose that much of information

# %%
data1 = data.drop(columns=vegetation_col[:-1] + forest_type)
data1.columns
# Out:
# Index(['Date', 'distance_fire_stations', 'distance_rivers', 'distance_roads',
#        'distance_powerlines', 'aspect', 'elevation', 'pop_dens', 'slope',
#        'anom_max_temp', 'anom_max_wind_vel', 'anom_avg_temp',
#        'anom_avg_rel_hum', 'anom_avg_soil', 'anom_sum_prec', 'max_temp',
#        'max_wind_vel', 'avg_temp', 'avg_wind_angle', 'avg_rel_hum', 'avg_soil',
#        'sum_prec', 'vegetation_class', 'Year', 'max_max_temp',
#        'yearly_avg_temp', 'ignition'],
#       dtype='object')

# %% [markdown]
# Now let's handle the yearly_avg_temp column, which contains 31% missing values.
# Since we know the ignition year, a reasonable strategy is to fill each NA with the average temperature of the corresponding year.
#
# Before doing that, let's take a look at the distribution to understand how this feature behaves.

# %%
sns.histplot(data=data1["yearly_avg_temp"])
plt.show()

# %% [markdown]
# The distribution looks symmetric and without heavy tails, so filling missing values with the yearly average should work well.

# %%
data2 = data1.copy()

for year in data2['Year'].unique() :
    mask = data2['Year'] == year
    year_avg = data2.loc[mask,'yearly_avg_temp'].mean()
    data2.loc[mask, "yearly_avg_temp"] = data2.loc[mask, "yearly_avg_temp"].fillna(year_avg)

# %%
data2.isna().any()
# Out:
# Date                      False
# distance_fire_stations    False
# distance_rivers           False
# distance_roads            False
# distance_powerlines       False
# aspect                    False
# elevation                 False
# pop_dens                  False
# slope                     False
# anom_max_temp             False
# anom_max_wind_vel         False
# anom_avg_temp             False
# anom_avg_rel_hum          False
# anom_avg_soil             False
# anom_sum_prec             False
# max_temp                  False
# max_wind_vel              False
# avg_temp                  False
# avg_wind_angle            False
# avg_rel_hum               False
# avg_soil                  False
# sum_prec                  False
# vegetation_class          False
# Year                      False
# max_max_temp              False
# yearly_avg_temp           False
# ignition                  False
# dtype: bool

# %% [markdown]
# We are done with NAs now !!

# %% [markdown]
# ## Distribution

# %%
data2.set_index(['Date'], inplace=True) # setting the date as index

# %%
data2.select_dtypes(['object', 'int']).columns
# Out:
# Index(['vegetation_class', 'Year', 'ignition'], dtype='object')

# %%
data2["ignition"].value_counts(normalize=True)
# Out:
# ignition
# 0    0.849296
# 1    0.150704
# Name: proportion, dtype: float64

# %% [markdown]
# Kinda imbalanced, so we will stratify during spliting

# %%
# barplot for the Year column
sns.histplot(data = data2, x = 'Year', hue='ignition',
             stat="proportion", common_norm=False, shrink=0.7, discrete=True)

plt.xticks(np.arange(2000,2022,2))
plt.tight_layout()
plt.show()

# %% [markdown]
# The year doesn't seems that discriminant.
# More than that, the year only indicates when the data point was recorded and does not provide any direct information related to ignition. Keeping it could introduce temporal bias without adding predictive power.

# %%
sns.histplot(data = data2, x = 'vegetation_class', hue='ignition',
             stat="proportion", common_norm=False, multiple="dodge", shrink=0.7)

plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
float_cols = data2.select_dtypes(include="float").columns
n_cols = len(float_cols)

# getting a clean layout
cols_per_row = 3
rows = int(np.ceil(n_cols / cols_per_row))

fig, axes = plt.subplots(rows, cols_per_row, figsize=(16, 4 * rows))
axes = axes.flatten()

for i, col in enumerate(float_cols):
    sns.histplot(
        data=data2,
        x=col,
        hue="ignition",
        bins=30,
        element="step",
        common_norm=False,
        stat='proportion',
        ax=axes[i]
    )
    axes[i].set_title(col)

# remove empty axes if the number of columns is not a multiple of 3
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# 1: Weird distribution for the average temp, more than 250 °C ?????
#
# 2: We can make the hypothesis that there is some diffenrence in the distribution depending on the target values for some features. Let's make a t-test

# %%
print(len(data2.loc[data2["avg_temp"] >= 250])/len(data2))
# Out:
# 0.5548343168406719

# %% [markdown]
# About 55 percent of the values in this column are unrealistically high, even if the unit were Fahrenheit. It might be in Kelvin, but I am not sure, so I will just drop the column because the data were not properly recorded. Also, as the plot below shows, the average temperature does not seem to differ between ignition and non ignition points anyway.

# %%
fig, ax = plt.subplots(1,2, figsize = (20,10))

# Temperatures below 60°C
sns.histplot(data = data2.loc[data2["avg_temp"] < 60], x='avg_temp', hue = 'ignition',
             ax = ax[0], element="step", common_norm=False,stat='proportion')
ax[0].set_title('Temprature below 60 degree °C')



# Temperatures above 60°C
sns.histplot(data = data2.loc[data2["avg_temp"] >= 60], x='avg_temp', hue = 'ignition',
             ax = ax[1],element="step", common_norm=False,stat='proportion')
ax[1].set_title('Temprature above 60 degree °C')


plt.show()

# %%
data3 = data2.drop(columns = ['avg_temp'])

# %%
from scipy.stats import ttest_ind

# %%
ignition = data3.loc[data3['ignition']==1]
not_ignition = data3.loc[data3['ignition']==0].sample(n = len(ignition), random_state=1) # since the target is unbalanced

alpha = 0.05

for col in data3.select_dtypes(include = 'float').columns :
    star, p_value = ttest_ind(not_ignition[col], ignition[col])
    if p_value < alpha :
        print(f'{col :-<25} HO rejected')
    else :
        print(f"{col :-<25} na")
# Out:
# distance_fire_stations--- HO rejected
# distance_rivers---------- HO rejected
# distance_roads----------- HO rejected
# distance_powerlines------ HO rejected
# aspect------------------- na
# elevation---------------- HO rejected
# pop_dens----------------- HO rejected
# slope-------------------- HO rejected
# anom_max_temp------------ HO rejected
# anom_max_wind_vel-------- HO rejected
# anom_avg_temp------------ HO rejected
# anom_avg_rel_hum--------- HO rejected
# anom_avg_soil------------ HO rejected
# anom_sum_prec------------ HO rejected
# max_temp----------------- HO rejected
# max_wind_vel------------- HO rejected
# avg_wind_angle----------- HO rejected
# avg_rel_hum-------------- HO rejected
# avg_soil----------------- HO rejected
# sum_prec----------------- HO rejected
# max_max_temp------------- HO rejected
# yearly_avg_temp---------- na

# %%
print(data3['yearly_avg_temp'].mean(), data3['yearly_avg_temp'].std())
# Out:
# 14.999734236855236 0.08365106607828247

# %% [markdown]
# Based on the t test results, all the features seem potentially useful for our prediction, except for yearly_avg_temp and aspect.
#
# This actually makes sense for yearly_avg_temp tho. I will probably remove that column later because the dispertion is way to small

# %% [markdown]
# ## Correlation

# %%
float_cols = data3.select_dtypes(include="float").columns

corr = data3[float_cols].corr(method= 'pearson')
mask = np.triu(np.ones_like(corr, dtype=bool))

f, ax = plt.subplots(figsize=(11, 11))

sns.heatmap(corr, mask=mask, vmin=-1, vmax=1,  center=0,linewidths=.5)
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# Insights :
# - max_max_temp looks like a linear combination of max_temp, so we should probably drop it.
# - The anomaly columns seem highly correlated with their normal average counterparts,
#   so their distributions might actually be the same, we’ll test that later.
# - distance_road and distance_rivers show a very high linear correlation.

# %%
# Is max_max_temp a linear combination of max_temp ?

sns.scatterplot(data=data3, x='max_temp', y='max_max_temp')
plt.title('max_temp vs max_max_temp')
plt.show()

# %% [markdown]
# Hmmm, It’s not a strict linear combination, but the boxplot stays pretty narrow, so dropping this feature seems reasonable.

# %% [markdown]
# For testing anom vs classic, i will do a ks test

# %%
from scipy.stats import ks_2samp

# %%
classic = ['max_temp','max_wind_vel', 'avg_rel_hum', 'avg_soil', 'sum_prec']
anom = ['anom_max_temp','anom_max_wind_vel', 'anom_avg_rel_hum',
        'anom_avg_soil', 'anom_sum_prec']

alpha = 0.05
for i in range(len(classic)) :
  avg = data3[classic[i]].mean()
  std = data3[classic[i]].std()
  standardized_classic = (data3[classic[i]] - avg)/std
  stat, p_value = ks_2samp(standardized_classic, data3[anom[i]])
  if p_value < alpha :
    print(f'{anom[i]} / {classic[i] :-<25} HO rejected')
  else:
    print(f"{anom[i]} / {classic[i] :-<25} na")
# Out:
# anom_max_temp / max_temp----------------- HO rejected
# anom_max_wind_vel / max_wind_vel------------- HO rejected
# anom_avg_rel_hum / avg_rel_hum-------------- HO rejected
# anom_avg_soil / avg_soil----------------- HO rejected
# anom_sum_prec / sum_prec----------------- HO rejected

# %% [markdown]
# Ok ok so my assumption was statisticaly false. Can't really explain the linear correl then.

# %%
corr['distance_roads']['distance_rivers']
# Out:
# np.float64(0.8102616506347041)

# %% [markdown]
# The correlation is a bit high, but since we’re not relying on a linear model
# (except maybe for a quick baseline), it's totally fine.

# %% [markdown]
# Now let's see the linear correlation between the target and other features

# %%
data3[float_cols.to_list() + ['ignition']].corr()['ignition'].sort_values(ascending=False)
# Out:
# ignition                  1.000000
# max_max_temp              0.295061
# max_temp                  0.295061
# pop_dens                  0.164212
# anom_max_temp             0.159961
# slope                     0.151001
# avg_wind_angle            0.052935
# elevation                 0.052914
# anom_avg_temp             0.040492
# anom_max_wind_vel         0.028027
# yearly_avg_temp           0.010210
# aspect                   -0.004457
# sum_prec                 -0.089895
# anom_sum_prec            -0.108783
# max_wind_vel             -0.110330
# avg_soil                 -0.136939
# anom_avg_rel_hum         -0.156299
# anom_avg_soil            -0.193019
# distance_powerlines      -0.205647
# distance_rivers          -0.218113
# distance_fire_stations   -0.228656
# distance_roads           -0.268259
# avg_rel_hum              -0.269676
# Name: ignition, dtype: float64

# %% [markdown]
# Not that much of correlation, a linear model like logistic regression will probably not be that great but still might be useful for a benchmark

# %% [markdown]
# # Preprocessing

# %%
# the final df

df_final = data3.drop(columns=['max_max_temp', 'Year', 'yearly_avg_temp'])

# %%
# print number of categories for vgetation_class

print(df_final['vegetation_class'].unique().shape[0])
# Out:
# 7

# %% [markdown]
# Let's do the prepocessing now,
#
# - Float features: we apply a StandardScaler. Tree-based models are scale-invariant, but we still standardize for consistency across all models.
#
# - vegetation_class: this feature has 7 categories. We will try both one-hot encoding and frequency encoding, then compare which option works best in practice.

# %%
pip install feature_engine
# Out:
# 435.43s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting feature_engine
#   Downloading feature_engine-1.9.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.18.2 in /opt/python/lib/python3.13/site-packages (from feature_engine) (2.4.2)
# Requirement already satisfied: pandas>=2.2.0 in /opt/python/lib/python3.13/site-packages (from feature_engine) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.4.0 in /opt/python/lib/python3.13/site-packages (from feature_engine) (1.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/python/lib/python3.13/site-packages (from feature_engine) (1.17.1)
# Requirement already satisfied: statsmodels>=0.11.1 in /opt/python/lib/python3.13/site-packages (from feature_engine) (0.14.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/python/lib/python3.13/site-packages (from pandas>=2.2.0->feature_engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/python/lib/python3.13/site-packages (from pandas>=2.2.0->feature_engine) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/python/lib/python3.13/site-packages (from pandas>=2.2.0->feature_engine) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->feature_engine) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn>=1.4.0->feature_engine) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn>=1.4.0->feature_engine) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /opt/python/lib/python3.13/site-packages (from statsmodels>=0.11.1->feature_engine) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /opt/python/lib/python3.13/site-packages (from statsmodels>=0.11.1->feature_engine) (26.0)
# Downloading feature_engine-1.9.4-py3-none-any.whl (243 kB)
# Installing collected packages: feature_engine
# Successfully installed feature_engine-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from feature_engine.encoding import CountFrequencyEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

# %%
# Splitting the dataset into features and target variable

X = df_final.drop(columns='ignition')

y = df_final['ignition']

# %%
float_cols = X.select_dtypes(include="float").columns.to_list()
cat_col = X.select_dtypes(include="object").columns.to_list()

# %%
# pipeline for one hot encoder

pipeline_one_hot = Pipeline([
    ('preprocessor_one_hot', ColumnTransformer(
        transformers=[
            ('num_pipe', StandardScaler(), float_cols),
            ('cat_pipe', OneHotEncoder(sparse_output=False), cat_col)]
))])

# pipeline for frequency encoder

pipeline_freq = Pipeline([
    ('preprocessor_freq', ColumnTransformer(
        transformers=[
            ('num', StandardScaler(), float_cols),
            ('cat', CountFrequencyEncoder(encoding_method='frequency'), cat_col)]
))])

# %%
# Function to get back a df from a pipeline transformed df
def pipeline_to_df(pipeline, X, prep_name):
    prep = pipeline.named_steps[prep_name]
    X_arr = prep.fit_transform(X)
    try:
        cols = prep.get_feature_names_out()
    except AttributeError:
        cols = X.columns
    return pd.DataFrame(X_arr, columns=cols, index=X.index)

X_oh_df   = pipeline_to_df(pipeline_one_hot, X, "preprocessor_one_hot")
X_freq_df = pipeline_to_df(pipeline_freq, X, "preprocessor_freq")
# Out:
# /opt/python/lib/python3.13/site-packages/feature_engine/variable_handling/_variable_type_checks.py:34: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   var = pd.to_datetime(column, utc=True)

# %%
# Train test split for both One Hot version and frequency version
# Note that we don't need to change y, the splitting is the same


X_train_OH, X_test_OH, y_train_, y_test_ = train_test_split(X_oh_df, y, random_state=1, stratify=y, train_size=0.7)
X_train_freq, X_test_freq, y_train_, y_test_ = train_test_split(X_freq_df, y, random_state=1, stratify=y, train_size=0.7)

# %%
X_train_freq.head()
# Out:
#             num__distance_fire_stations  num__distance_rivers  \
# Date
# 2016-12-18                    -0.655100             -0.580933
# 2018-06-13                     3.850558              1.084270
# 2005-07-26                    -0.915700             -0.793931
# 2018-05-05                    -1.136657             -0.660872
# 2016-03-23                     0.688706              1.681995
#
#             num__distance_roads  num__distance_powerlines  num__aspect  \
# Date
# 2016-12-18            -0.707997                 -0.826544     1.280610
# 2018-06-13             3.717674                  0.962567     0.029851
# 2005-07-26            -0.693043                 -0.934522    -0.472748
# 2018-05-05            -0.693043                 -0.672069     0.176553
# 2016-03-23             1.566785                  0.419573     0.029851
#
#             num__elevation  num__pop_dens  num__slope  num__anom_max_temp  \
# Date
# 2016-12-18        1.174305      -0.115948    1.683229            0.825208
# 2018-06-13       -0.905974      -0.118128   -0.720201            2.575034
# 2005-07-26       -0.161453      -0.113487    0.468511            0.018213
# 2018-05-05       -0.095760      -0.025998   -0.398636            1.450740
# 2016-03-23       -0.905974      -0.118128   -0.720201           -1.325771
#
#             num__anom_max_wind_vel  num__anom_avg_temp  num__anom_avg_rel_hum  \
# Date
# 2016-12-18                1.007953           -0.324051               0.098810
# 2018-06-13               -0.061851            0.649424              -0.382509
# 2005-07-26                0.518608           -1.491373               0.417574
# 2018-05-05               -0.020375            0.951264               0.220158
# 2016-03-23               -1.196472           -1.250428              -0.089741
#
#             num__anom_avg_soil  num__anom_sum_prec  num__max_temp  \
# Date
# 2016-12-18            0.290021           -1.022851       0.695580
# 2018-06-13           -1.647820           -1.142404       1.891119
# 2005-07-26            0.320905           -0.849392      -1.748649
# 2018-05-05            0.654071            1.475492      -0.014682
# 2016-03-23           -0.175812           -0.418729      -0.535969
#
#             num__max_wind_vel  num__avg_wind_angle  num__avg_rel_hum  \
# Date
# 2016-12-18          -0.092919             1.545680         -0.782970
# 2018-06-13          -0.128842            -1.569282         -0.647424
# 2005-07-26          -0.432283             1.662510          1.255238
# 2018-05-05          -0.658058            -0.812947         -0.300037
# 2016-03-23           0.132949            -0.292764          0.067448
#
#             num__avg_soil  num__sum_prec  cat__vegetation_class
# Date
# 2016-12-18       1.109859       0.183246               0.439083
# 2018-06-13      -2.127805      -0.514875               0.368044
# 2005-07-26       1.516757       1.185962               0.439083
# 2018-05-05       0.398336      -0.111238               0.174807
# 2016-03-23      -0.729984      -0.514875               0.368044

# %% [markdown]
# # Modelling

# %% [markdown]
# We will test multiple models:
# - Logistic regression
# - Random Forest
# - XGboost
# - SVM
# - Neural network
#
# Then we will select the best one and try to optimize it.
#
# To evaluate the performance of the model, we use F1-score, recall, and PR-AUC, which are appropriate metrics since the target is unbalanced.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
import tensorflow as tf
from tensorflow.keras import layers, models, Input
from tensorflow.keras.metrics import Precision as precision
from tensorflow.keras.metrics import Recall as recall
from tensorflow.keras.metrics import AUC as auc
from sklearn.metrics import f1_score, recall_score, average_precision_score, precision_score
import time
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774020606.779749    7040 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1774020606.780665    7040 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1774020606.843038    7040 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774020638.792411    7040 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1774020638.792896    7040 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# Compute the positive class weight because the target is imbalanced
pos_class_weight = (len(y) - np.sum(y)) / np.sum(y)
weight = {0:1, 1:pos_class_weight}

# Listing our models
dico_models = {'Logistic regression' : LogisticRegression(class_weight=weight, random_state=0),
          'Random forest' : RandomForestClassifier(class_weight='balanced_subsample', random_state=0),
          'XGboost' : XGBClassifier(scale_pos_weight = pos_class_weight, random_state=0),
          'SVM' : SVC(class_weight=weight, probability=True, random_state=0)}

# %%
# Fonction to get the training time of a model in a nice format

def format_time(seconds):
    hours = int(seconds // 3600)
    minutes = int((seconds % 3600) // 60)
    secs = int(seconds % 60)
    return hours, minutes, secs

# %%
# Fonction to store each models results

def models_evaluation(x_train, x_test, y_train, y_test):
  results = {}
  for model_name, model in dico_models.items():

    start = time.time()
    model.fit(x_train, y_train)
    duration = time.time() - start

    # convert duration to h/m/s
    h, m, s = format_time(duration)

    # prediction
    y_pred = model.predict(x_test)

    # probabilities for PR-AUC
    y_score = model.predict_proba(x_test)[:, 1]

    # storage
    results[model_name] = {'f1_score' : f1_score(y_test, y_pred),
                           'precision' : precision_score(y_test, y_pred),
                           'recall' : recall_score(y_test, y_pred),
                           'pr_auc' : average_precision_score(y_test, y_score),
                           'fitted_model' : model, # will be useful for the Random Forest features importance
                           'name' : model_name}

    # pretty print
    print(f"{model_name} completed in {h}h {m}m {s}s")
  return (results)

# %%
results_OH = models_evaluation(X_train_OH, X_test_OH, y_train_, y_test_)
# Out:
# Logistic regression completed in 0h 0m 0s
# Random forest completed in 0h 0m 4s
# XGboost completed in 0h 0m 0s
# SVM completed in 0h 0m 30s

# %%
results_freq = models_evaluation(X_train_freq, X_test_freq, y_train_, y_test_)
# Out:
# Logistic regression completed in 0h 0m 0s
# Random forest completed in 0h 0m 4s
# XGboost completed in 0h 0m 0s
# SVM completed in 0h 0m 28s

# %% [markdown]
# Let' compute a fonction to get a dataframe from the results dictionnary. It will be useful for plotting the metrics

# %%
def dico_results_to_df(results):
    rows = []

    for model_name, metrics in results.items():
        rows.append({
            "name": metrics["name"],
            "recall": metrics["recall"],
            "precision": metrics["precision"],
            "f1_score": metrics["f1_score"],
            "pr_auc": metrics["pr_auc"]
        })

    df = pd.DataFrame(rows)
    return df

# %%
# Comparing One Hot Encoder vs Frenquency encoder

results_OH_df = dico_results_to_df(results_OH).round(2)

results_freq_df = dico_results_to_df(results_freq).round(2)

print ('One Hot Encoding\n', results_OH_df, '\n\n\nFrequency Encoding\n',results_freq_df)
# Out:
# One Hot Encoding
#                    name  recall  precision  f1_score  pr_auc
# 0  Logistic regression    0.85       0.38      0.53    0.53
# 1        Random forest    0.43       0.78      0.56    0.71
# 2              XGboost    0.70       0.59      0.64    0.71
# 3                  SVM    0.89       0.43      0.58    0.56
#
#
# Frequency Encoding
#                    name  recall  precision  f1_score  pr_auc
# 0  Logistic regression    0.85       0.38      0.52    0.53
# 1        Random forest    0.44       0.77      0.56    0.70
# 2              XGboost    0.72       0.59      0.65    0.71
# 3                  SVM    0.89       0.42      0.57    0.54

# %% [markdown]
# For our problem, frequency encoding is equivalent to One hot encoding.
#
# We are keeping the One hot version

# %%
# cool little list of the metrics we want to show
metrics = ["f1_score", "recall", "precision", "pr_auc"]

# reshape the results into a long-format table
long_df = results_OH_df.melt(
    id_vars="name",
    value_vars=metrics,
    var_name="metric",
    value_name="score"
)

# nicer names for the plot
metric_titles = {
    "f1_score": "F1-score",
    "recall": "Recall",
    "precision": "Precision",
    "pr_auc": "PR-AUC"
}
long_df["metric"] = long_df["metric"].map(metric_titles)

# Plot
plt.figure(figsize=(12, 6))

sns.barplot(
    data=long_df,
    x="metric",
    y="score",
    hue="name"
)

# cleaner plot
plt.ylim(0, 1)
plt.xlabel("")
plt.ylabel("Score")
plt.title("How each models performs")
plt.legend(title="Model", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

plt.show()

# %% [markdown]
# Among the tested models, XGBoost achieved the best overall performance, with the highest F1-score and PR-AUC. It provides a good balance between recall and precision, detecting ignition points without generating too many false alarms. Logistic Regression and SVM achieved very high recall but produced a large number of false positives, resulting in low precision. On the other hand, Random Forest was overly conservative, with strong precision but a low recall, meaning it missed many actual ignition points. Overall, XGBoost appears to offer the most reliable trade-off for this imbalanced classification task.
#
# Let's compare XGboost with a neural network.

# %%
input_dim = X_train_OH.shape[1]

model_nn = models.Sequential()

# input layer
model_nn.add(Input(shape=(input_dim,)))

# hidden layers
model_nn.add(layers.Dense(128, activation='sigmoid', kernel_initializer='glorot_uniform'))
model_nn.add(layers.Dropout(0.3)) # dropout method to prevent from overfitting

model_nn.add(layers.Dense(64, activation='sigmoid', kernel_initializer='glorot_uniform'))
model_nn.add(layers.Dropout(0.3))

model_nn.add(layers.Dense(32, activation='sigmoid', kernel_initializer='glorot_uniform'))
model_nn.add(layers.Dropout(0.3))

model_nn.add(layers.Dense(16, activation='sigmoid', kernel_initializer='glorot_uniform'))
model_nn.add(layers.Dropout(0.3))

# output layer: sigmoid for binary classification
model_nn.add(layers.Dense(1, activation='sigmoid'))

model_nn.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=[precision(name='precision'),
                       auc(name='pr_auc', curve='PR'),
                       recall(name='recall'),
                       ])
# Out:
# E0000 00:00:1774020734.306775    7040 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
history = model_nn.fit(X_train_OH, y_train_, epochs=100, validation_data = (X_test_OH, y_test_),
                    class_weight=weight, batch_size= 256)
# Out:
# Epoch 1/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.2611 - pr_auc: 0.1548 - precision: 0.1526 - recall: 0.3429 - val_loss: 0.7151 - val_pr_auc: 0.3109 - val_precision: 0.1507 - val_recall: 1.0000
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.1964 - pr_auc: 0.1624 - precision: 0.1646 - recall: 0.4867 - val_loss: 0.6619 - val_pr_auc: 0.4686 - val_precision: 0.3355 - val_recall: 0.8363
# Epoch 3/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0843 - pr_auc: 0.2652 - precision: 0.2437 - recall: 0.6076 - val_loss: 0.5605 - val_pr_auc: 0.4923 - val_precision: 0.3177 - val_recall: 0.8926
# Epoch 4/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8990 - pr_auc: 0.3829 - precision: 0.3342 - recall: 0.7900 - val_loss: 0.4750 - val_pr_auc: 0.5095 - val_precision: 0.3623 - val_recall: 0.8655
# Epoch 5/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.8488 - pr_auc: 0.3957 - precision: 0.3422 - recall: 0.8361 - val_loss: 0.4954 - val_pr_auc: 0.5081 - val_precision: 0.3458 - val_recall: 0.8835
# Epoch 6/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.8233 - pr_auc: 0.4027 - precision: 0.3545 - recall: 0.8584 - val_loss: 0.4685 - val_pr_auc: 0.5239 - val_precision: 0.3580 - val_recall: 0.8745
# Epoch 7/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8068 - pr_auc: 0.4058 - precision: 0.3454 - recall: 0.8709 - val_loss: 0.4571 - val_pr_auc: 0.5251 - val_precision: 0.3596 - val_recall: 0.8785
# Epoch 8/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.8089 - pr_auc: 0.4121 - precision: 0.3461 - recall: 0.8653 - val_loss: 0.4930 - val_pr_auc: 0.5246 - val_precision: 0.3389 - val_recall: 0.9016
# Epoch 9/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.7898 - pr_auc: 0.4280 - precision: 0.3510 - recall: 0.8765 - val_loss: 0.5085 - val_pr_auc: 0.5189 - val_precision: 0.3343 - val_recall: 0.9177
# Epoch 10/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.7906 - pr_auc: 0.4183 - precision: 0.3473 - recall: 0.8705 - val_loss: 0.4600 - val_pr_auc: 0.5258 - val_precision: 0.3541 - val_recall: 0.8795
# Epoch 11/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.7870 - pr_auc: 0.4266 - precision: 0.3495 - recall: 0.8778 - val_loss: 0.4417 - val_pr_auc: 0.5279 - val_precision: 0.3649 - val_recall: 0.8695
# Epoch 12/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.7816 - pr_auc: 0.4235 - precision: 0.3490 - recall: 0.8692 - val_loss: 0.4786 - val_pr_auc: 0.5254 - val_precision: 0.3446 - val_recall: 0.8986
# Epoch 13/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.7780 - pr_auc: 0.4380 - precision: 0.3501 - recall: 0.8774 - val_loss: 0.4655 - val_pr_auc: 0.5274 - val_precision: 0.3511 - val_recall: 0.8886
# Epoch 14/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.7775 - pr_auc: 0.4318 - precision: 0.3492 - recall: 0.8657 - val_loss: 0.4554 - val_pr_auc: 0.5295 - val_precision: 0.3584 - val_recall: 0.8805
# Epoch 15/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.7656 - pr_auc: 0.4441 - precision: 0.3513 - recall: 0.8739 - val_loss: 0.4523 - val_pr_auc: 0.5287 - val_precision: 0.3586 - val_recall: 0.8785
# Epoch 16/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.7676 - pr_auc: 0.4506 - precision: 0.3485 - recall: 0.8718 - val_loss: 0.4319 - val_pr_auc: 0.5255 - val_precision: 0.3699 - val_recall: 0.8604
# Epoch 17/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.7668 - pr_auc: 0.4538 - precision: 0.3557 - recall: 0.8705 - val_loss: 0.4483 - val_pr_auc: 0.5260 - val_precision: 0.3624 - val_recall: 0.8685
# Epoch 18/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7658 - pr_auc: 0.4524 - precision: 0.3540 - recall: 0.8653 - val_loss: 0.4855 - val_pr_auc: 0.5262 - val_precision: 0.3437 - val_recall: 0.8986
# Epoch 19/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.7580 - pr_auc: 0.4550 - precision: 0.3513 - recall: 0.8726 - val_loss: 0.4572 - val_pr_auc: 0.5264 - val_precision: 0.3578 - val_recall: 0.8765
# Epoch 20/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.7611 - pr_auc: 0.4673 - precision: 0.3486 - recall: 0.8713 - val_loss: 0.4609 - val_pr_auc: 0.5255 - val_precision: 0.3539 - val_recall: 0.8855
# Epoch 21/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.7538 - pr_auc: 0.4593 - precision: 0.3557 - recall: 0.8657 - val_loss: 0.4551 - val_pr_auc: 0.5293 - val_precision: 0.3578 - val_recall: 0.8745
# Epoch 22/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7555 - pr_auc: 0.4660 - precision: 0.3539 - recall: 0.8718 - val_loss: 0.4671 - val_pr_auc: 0.5305 - val_precision: 0.3515 - val_recall: 0.8946
# Epoch 23/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.7540 - pr_auc: 0.4667 - precision: 0.3549 - recall: 0.8666 - val_loss: 0.4814 - val_pr_auc: 0.5324 - val_precision: 0.3438 - val_recall: 0.8996
# Epoch 24/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7479 - pr_auc: 0.4584 - precision: 0.3492 - recall: 0.8606 - val_loss: 0.4583 - val_pr_auc: 0.5311 - val_precision: 0.3532 - val_recall: 0.8886
# Epoch 25/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7511 - pr_auc: 0.4741 - precision: 0.3482 - recall: 0.8653 - val_loss: 0.4580 - val_pr_auc: 0.5338 - val_precision: 0.3531 - val_recall: 0.8855
# Epoch 26/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7461 - pr_auc: 0.4786 - precision: 0.3582 - recall: 0.8576 - val_loss: 0.4597 - val_pr_auc: 0.5363 - val_precision: 0.3594 - val_recall: 0.8765
# Epoch 27/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7404 - pr_auc: 0.4830 - precision: 0.3610 - recall: 0.8649 - val_loss: 0.4576 - val_pr_auc: 0.5374 - val_precision: 0.3581 - val_recall: 0.8765
# Epoch 28/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7424 - pr_auc: 0.4838 - precision: 0.3545 - recall: 0.8636 - val_loss: 0.4599 - val_pr_auc: 0.5370 - val_precision: 0.3535 - val_recall: 0.8865
# Epoch 29/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.7411 - pr_auc: 0.4839 - precision: 0.3608 - recall: 0.8662 - val_loss: 0.4561 - val_pr_auc: 0.5379 - val_precision: 0.3543 - val_recall: 0.8815
# Epoch 30/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7428 - pr_auc: 0.4910 - precision: 0.3571 - recall: 0.8722 - val_loss: 0.4492 - val_pr_auc: 0.5433 - val_precision: 0.3615 - val_recall: 0.8755
# Epoch 31/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7380 - pr_auc: 0.4872 - precision: 0.3582 - recall: 0.8688 - val_loss: 0.4613 - val_pr_auc: 0.5408 - val_precision: 0.3526 - val_recall: 0.8865
# Epoch 32/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7360 - pr_auc: 0.4911 - precision: 0.3537 - recall: 0.8756 - val_loss: 0.4478 - val_pr_auc: 0.5476 - val_precision: 0.3556 - val_recall: 0.8815
# Epoch 33/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7385 - pr_auc: 0.4838 - precision: 0.3554 - recall: 0.8670 - val_loss: 0.4755 - val_pr_auc: 0.5486 - val_precision: 0.3454 - val_recall: 0.8986
# Epoch 34/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7327 - pr_auc: 0.4929 - precision: 0.3563 - recall: 0.8756 - val_loss: 0.4322 - val_pr_auc: 0.5517 - val_precision: 0.3727 - val_recall: 0.8655
# Epoch 35/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7408 - pr_auc: 0.4905 - precision: 0.3591 - recall: 0.8649 - val_loss: 0.4525 - val_pr_auc: 0.5477 - val_precision: 0.3540 - val_recall: 0.8825
# Epoch 36/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7368 - pr_auc: 0.4939 - precision: 0.3565 - recall: 0.8756 - val_loss: 0.4476 - val_pr_auc: 0.5509 - val_precision: 0.3609 - val_recall: 0.8765
# Epoch 37/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7336 - pr_auc: 0.4997 - precision: 0.3605 - recall: 0.8705 - val_loss: 0.4623 - val_pr_auc: 0.5483 - val_precision: 0.3552 - val_recall: 0.8855
# Epoch 38/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7347 - pr_auc: 0.4960 - precision: 0.3609 - recall: 0.8670 - val_loss: 0.4312 - val_pr_auc: 0.5568 - val_precision: 0.3753 - val_recall: 0.8685
# Epoch 39/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7324 - pr_auc: 0.5050 - precision: 0.3615 - recall: 0.8735 - val_loss: 0.4498 - val_pr_auc: 0.5554 - val_precision: 0.3611 - val_recall: 0.8825
# Epoch 40/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7311 - pr_auc: 0.4915 - precision: 0.3604 - recall: 0.8632 - val_loss: 0.4585 - val_pr_auc: 0.5585 - val_precision: 0.3559 - val_recall: 0.8855
# Epoch 41/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7326 - pr_auc: 0.4966 - precision: 0.3575 - recall: 0.8649 - val_loss: 0.4509 - val_pr_auc: 0.5575 - val_precision: 0.3547 - val_recall: 0.8876
# Epoch 42/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7248 - pr_auc: 0.5089 - precision: 0.3655 - recall: 0.8817 - val_loss: 0.4507 - val_pr_auc: 0.5584 - val_precision: 0.3585 - val_recall: 0.8805
# Epoch 43/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7228 - pr_auc: 0.5030 - precision: 0.3587 - recall: 0.8692 - val_loss: 0.4429 - val_pr_auc: 0.5627 - val_precision: 0.3757 - val_recall: 0.8665
# Epoch 44/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7279 - pr_auc: 0.5026 - precision: 0.3629 - recall: 0.8688 - val_loss: 0.4336 - val_pr_auc: 0.5639 - val_precision: 0.3710 - val_recall: 0.8695
# Epoch 45/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7271 - pr_auc: 0.5054 - precision: 0.3652 - recall: 0.8709 - val_loss: 0.4447 - val_pr_auc: 0.5661 - val_precision: 0.3667 - val_recall: 0.8765
# Epoch 46/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7297 - pr_auc: 0.4992 - precision: 0.3646 - recall: 0.8632 - val_loss: 0.4451 - val_pr_auc: 0.5640 - val_precision: 0.3694 - val_recall: 0.8715
# Epoch 47/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.7254 - pr_auc: 0.5023 - precision: 0.3630 - recall: 0.8623 - val_loss: 0.4373 - val_pr_auc: 0.5657 - val_precision: 0.3784 - val_recall: 0.8655
# Epoch 48/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7286 - pr_auc: 0.4986 - precision: 0.3667 - recall: 0.8640 - val_loss: 0.4384 - val_pr_auc: 0.5645 - val_precision: 0.3747 - val_recall: 0.8675
# Epoch 49/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7132 - pr_auc: 0.5198 - precision: 0.3664 - recall: 0.8614 - val_loss: 0.4322 - val_pr_auc: 0.5669 - val_precision: 0.3750 - val_recall: 0.8705
# Epoch 50/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7184 - pr_auc: 0.5215 - precision: 0.3644 - recall: 0.8744 - val_loss: 0.4302 - val_pr_auc: 0.5672 - val_precision: 0.3833 - val_recall: 0.8594
# Epoch 51/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7184 - pr_auc: 0.5240 - precision: 0.3706 - recall: 0.8649 - val_loss: 0.4522 - val_pr_auc: 0.5683 - val_precision: 0.3715 - val_recall: 0.8765
# Epoch 52/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7237 - pr_auc: 0.4943 - precision: 0.3654 - recall: 0.8726 - val_loss: 0.4291 - val_pr_auc: 0.5694 - val_precision: 0.3852 - val_recall: 0.8554
# Epoch 53/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7234 - pr_auc: 0.5161 - precision: 0.3685 - recall: 0.8623 - val_loss: 0.4443 - val_pr_auc: 0.5710 - val_precision: 0.3757 - val_recall: 0.8635
# Epoch 54/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7173 - pr_auc: 0.4969 - precision: 0.3679 - recall: 0.8632 - val_loss: 0.4299 - val_pr_auc: 0.5728 - val_precision: 0.3857 - val_recall: 0.8574
# Epoch 55/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7145 - pr_auc: 0.5199 - precision: 0.3769 - recall: 0.8679 - val_loss: 0.4333 - val_pr_auc: 0.5740 - val_precision: 0.3818 - val_recall: 0.8624
# Epoch 56/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7162 - pr_auc: 0.5275 - precision: 0.3701 - recall: 0.8645 - val_loss: 0.4411 - val_pr_auc: 0.5744 - val_precision: 0.3743 - val_recall: 0.8715
# Epoch 57/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7140 - pr_auc: 0.5221 - precision: 0.3677 - recall: 0.8636 - val_loss: 0.4271 - val_pr_auc: 0.5718 - val_precision: 0.3844 - val_recall: 0.8594
# Epoch 58/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7165 - pr_auc: 0.5173 - precision: 0.3696 - recall: 0.8640 - val_loss: 0.4608 - val_pr_auc: 0.5719 - val_precision: 0.3624 - val_recall: 0.8805
# Epoch 59/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7215 - pr_auc: 0.5070 - precision: 0.3690 - recall: 0.8614 - val_loss: 0.4564 - val_pr_auc: 0.5735 - val_precision: 0.3655 - val_recall: 0.8795
# Epoch 60/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7107 - pr_auc: 0.5268 - precision: 0.3649 - recall: 0.8761 - val_loss: 0.4195 - val_pr_auc: 0.5752 - val_precision: 0.3897 - val_recall: 0.8544
# Epoch 61/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7160 - pr_auc: 0.5089 - precision: 0.3745 - recall: 0.8705 - val_loss: 0.4218 - val_pr_auc: 0.5766 - val_precision: 0.3878 - val_recall: 0.8534
# Epoch 62/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7107 - pr_auc: 0.5287 - precision: 0.3736 - recall: 0.8713 - val_loss: 0.4469 - val_pr_auc: 0.5776 - val_precision: 0.3714 - val_recall: 0.8725
# Epoch 63/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7133 - pr_auc: 0.5242 - precision: 0.3685 - recall: 0.8640 - val_loss: 0.4334 - val_pr_auc: 0.5768 - val_precision: 0.3799 - val_recall: 0.8655
# Epoch 64/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7153 - pr_auc: 0.5153 - precision: 0.3709 - recall: 0.8769 - val_loss: 0.4343 - val_pr_auc: 0.5791 - val_precision: 0.3800 - val_recall: 0.8665
# Epoch 65/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7148 - pr_auc: 0.5177 - precision: 0.3736 - recall: 0.8645 - val_loss: 0.4344 - val_pr_auc: 0.5786 - val_precision: 0.3832 - val_recall: 0.8645
# Epoch 66/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7137 - pr_auc: 0.5242 - precision: 0.3766 - recall: 0.8623 - val_loss: 0.4184 - val_pr_auc: 0.5805 - val_precision: 0.3894 - val_recall: 0.8534
# Epoch 67/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7120 - pr_auc: 0.5209 - precision: 0.3712 - recall: 0.8726 - val_loss: 0.4354 - val_pr_auc: 0.5785 - val_precision: 0.3814 - val_recall: 0.8665
# Epoch 68/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7050 - pr_auc: 0.5177 - precision: 0.3703 - recall: 0.8645 - val_loss: 0.4237 - val_pr_auc: 0.5814 - val_precision: 0.3808 - val_recall: 0.8624
# Epoch 69/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7081 - pr_auc: 0.5349 - precision: 0.3737 - recall: 0.8632 - val_loss: 0.4299 - val_pr_auc: 0.5808 - val_precision: 0.3818 - val_recall: 0.8624
# Epoch 70/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6955 - pr_auc: 0.5273 - precision: 0.3763 - recall: 0.8709 - val_loss: 0.4000 - val_pr_auc: 0.5829 - val_precision: 0.3972 - val_recall: 0.8404
# Epoch 71/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7033 - pr_auc: 0.5231 - precision: 0.3755 - recall: 0.8670 - val_loss: 0.4389 - val_pr_auc: 0.5824 - val_precision: 0.3702 - val_recall: 0.8735
# Epoch 72/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6998 - pr_auc: 0.5318 - precision: 0.3777 - recall: 0.8769 - val_loss: 0.4395 - val_pr_auc: 0.5827 - val_precision: 0.3723 - val_recall: 0.8695
# Epoch 73/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7089 - pr_auc: 0.5253 - precision: 0.3742 - recall: 0.8744 - val_loss: 0.4386 - val_pr_auc: 0.5838 - val_precision: 0.3656 - val_recall: 0.8795
# Epoch 74/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7020 - pr_auc: 0.5326 - precision: 0.3745 - recall: 0.8696 - val_loss: 0.4537 - val_pr_auc: 0.5816 - val_precision: 0.3691 - val_recall: 0.8765
# Epoch 75/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7028 - pr_auc: 0.5409 - precision: 0.3696 - recall: 0.8683 - val_loss: 0.4432 - val_pr_auc: 0.5830 - val_precision: 0.3775 - val_recall: 0.8645
# Epoch 76/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7045 - pr_auc: 0.5294 - precision: 0.3805 - recall: 0.8735 - val_loss: 0.4328 - val_pr_auc: 0.5853 - val_precision: 0.3818 - val_recall: 0.8594
# Epoch 77/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6928 - pr_auc: 0.5398 - precision: 0.3823 - recall: 0.8701 - val_loss: 0.4274 - val_pr_auc: 0.5852 - val_precision: 0.3821 - val_recall: 0.8604
# Epoch 78/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7002 - pr_auc: 0.5333 - precision: 0.3795 - recall: 0.8744 - val_loss: 0.4512 - val_pr_auc: 0.5857 - val_precision: 0.3731 - val_recall: 0.8755
# Epoch 79/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7031 - pr_auc: 0.5430 - precision: 0.3705 - recall: 0.8627 - val_loss: 0.4342 - val_pr_auc: 0.5855 - val_precision: 0.3839 - val_recall: 0.8594
# Epoch 80/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6993 - pr_auc: 0.5342 - precision: 0.3780 - recall: 0.8692 - val_loss: 0.4175 - val_pr_auc: 0.5888 - val_precision: 0.3857 - val_recall: 0.8604
# Epoch 81/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7010 - pr_auc: 0.5345 - precision: 0.3829 - recall: 0.8657 - val_loss: 0.4245 - val_pr_auc: 0.5880 - val_precision: 0.3840 - val_recall: 0.8655
# Epoch 82/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6959 - pr_auc: 0.5419 - precision: 0.3757 - recall: 0.8696 - val_loss: 0.4151 - val_pr_auc: 0.5903 - val_precision: 0.3896 - val_recall: 0.8574
# Epoch 83/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6929 - pr_auc: 0.5445 - precision: 0.3777 - recall: 0.8670 - val_loss: 0.4425 - val_pr_auc: 0.5878 - val_precision: 0.3748 - val_recall: 0.8735
# Epoch 84/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6916 - pr_auc: 0.5340 - precision: 0.3815 - recall: 0.8696 - val_loss: 0.4363 - val_pr_auc: 0.5864 - val_precision: 0.3740 - val_recall: 0.8705
# Epoch 85/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6960 - pr_auc: 0.5463 - precision: 0.3769 - recall: 0.8731 - val_loss: 0.4069 - val_pr_auc: 0.5899 - val_precision: 0.3986 - val_recall: 0.8544
# Epoch 86/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.7040 - pr_auc: 0.5382 - precision: 0.3758 - recall: 0.8739 - val_loss: 0.4068 - val_pr_auc: 0.5894 - val_precision: 0.3896 - val_recall: 0.8574
# Epoch 87/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7003 - pr_auc: 0.5362 - precision: 0.3740 - recall: 0.8744 - val_loss: 0.4159 - val_pr_auc: 0.5881 - val_precision: 0.3846 - val_recall: 0.8614
# Epoch 88/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6944 - pr_auc: 0.5417 - precision: 0.3802 - recall: 0.8709 - val_loss: 0.4188 - val_pr_auc: 0.5891 - val_precision: 0.3873 - val_recall: 0.8574
# Epoch 89/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6919 - pr_auc: 0.5521 - precision: 0.3805 - recall: 0.8636 - val_loss: 0.4161 - val_pr_auc: 0.5920 - val_precision: 0.3866 - val_recall: 0.8604
# Epoch 90/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6892 - pr_auc: 0.5408 - precision: 0.3801 - recall: 0.8769 - val_loss: 0.4259 - val_pr_auc: 0.5923 - val_precision: 0.3826 - val_recall: 0.8685
# Epoch 91/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6902 - pr_auc: 0.5480 - precision: 0.3815 - recall: 0.8692 - val_loss: 0.4144 - val_pr_auc: 0.5917 - val_precision: 0.3866 - val_recall: 0.8624
# Epoch 92/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6945 - pr_auc: 0.5435 - precision: 0.3750 - recall: 0.8799 - val_loss: 0.4229 - val_pr_auc: 0.5920 - val_precision: 0.3829 - val_recall: 0.8685
# Epoch 93/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6894 - pr_auc: 0.5424 - precision: 0.3751 - recall: 0.8804 - val_loss: 0.4106 - val_pr_auc: 0.5925 - val_precision: 0.3905 - val_recall: 0.8574
# Epoch 94/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6930 - pr_auc: 0.5391 - precision: 0.3798 - recall: 0.8761 - val_loss: 0.4208 - val_pr_auc: 0.5926 - val_precision: 0.3836 - val_recall: 0.8715
# Epoch 95/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6815 - pr_auc: 0.5499 - precision: 0.3757 - recall: 0.8722 - val_loss: 0.4186 - val_pr_auc: 0.5922 - val_precision: 0.3872 - val_recall: 0.8685
# Epoch 96/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6876 - pr_auc: 0.5457 - precision: 0.3742 - recall: 0.8713 - val_loss: 0.4019 - val_pr_auc: 0.5937 - val_precision: 0.3940 - val_recall: 0.8584
# Epoch 97/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6894 - pr_auc: 0.5555 - precision: 0.3812 - recall: 0.8696 - val_loss: 0.4139 - val_pr_auc: 0.5934 - val_precision: 0.3918 - val_recall: 0.8594
# Epoch 98/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6845 - pr_auc: 0.5506 - precision: 0.3780 - recall: 0.8683 - val_loss: 0.4212 - val_pr_auc: 0.5933 - val_precision: 0.3778 - val_recall: 0.8735
# Epoch 99/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6889 - pr_auc: 0.5458 - precision: 0.3770 - recall: 0.8774 - val_loss: 0.4257 - val_pr_auc: 0.5940 - val_precision: 0.3793 - val_recall: 0.8735
# Epoch 100/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6892 - pr_auc: 0.5536 - precision: 0.3801 - recall: 0.8735 - val_loss: 0.3906 - val_pr_auc: 0.5965 - val_precision: 0.4030 - val_recall: 0.8484

# %%
# Manually computing the F1-score, since keras.metrics.F1Score was not behaving as expected

train_prec = np.array(history.history["precision"])
train_rec  = np.array(history.history["recall"])

val_prec = np.array(history.history["val_precision"])
val_rec  = np.array(history.history["val_recall"])

history.history["f1_score"] = 2 * (train_prec * train_rec) / (train_prec + train_rec + 1e-8)
history.history["val_f1_score"] = 2 * (val_prec * val_rec) / (val_prec + val_rec + 1e-8)

# %%
# Metrics we want to visualize across training
metrics_to_plot = ["loss", "recall", "precision", "pr_auc", 'f1_score']

# XGBoost benchmark scores to compare against the neural network curves
xgb_scores = {
    "loss": None,
    "recall": 0.70,
    "precision": 0.59,
    "pr_auc": 0.71,
    "f1_score": 0.64
}

plt.figure(figsize=(17,13))

for i, metric in enumerate(metrics_to_plot, 1):
    plt.subplot(3, 2, i)
    sns.lineplot(history.history[metric], label=f"Train {metric}")
    sns.lineplot(history.history[f"val_{metric}"], label=f"Val {metric}")
    plt.title(metric)

    plt.grid(True)

    # Add a horizontal line showing the XGBoost performance
    if xgb_scores[metric] is not None:
        plt.axhline(
            y=xgb_scores[metric],
            color="red",
            linestyle="--",
            linewidth=2,
            label="XGBoost score"
        )
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Although the neural network achieves a very high recall, the XGBoost model provides a much better overall balance, with higher precision, F1-score and PR-AUC. Given its superior performance, greater stability and suitability for tabular data, XGBoost was selected as the primary model to optimize.

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer

# %%
xgb = XGBClassifier(
    objective="binary:logistic",
    eval_metric="aucpr",
    scale_pos_weight = pos_class_weight,
    n_jobs=-1
)

# Define the hyperparameter search space
param_dist = {
    "n_estimators": [300, 500, 700],
    "learning_rate": [0.01, 0.05, 0.1],
    "max_depth": [3, 4, 5, 6, 7],
    "subsample": [0.6, 0.8, 1.0],
    "colsample_bytree": [0.6, 0.8, 1.0],
    "min_child_weight": [1, 3, 5, 7],
    "gamma": [0, 1, 3]
}


# Define scoring: we optimize PR-AUC (the best metric for imbalance)

scorer = make_scorer(average_precision_score, response_method='predict_proba')

# 4. RandomizedSearchCV setup

random_search = RandomizedSearchCV(
    error_score='raise',       # helps if i get an error
    estimator=xgb,
    param_distributions=param_dist,
    n_iter=20,                 # number of random configurations tested
    scoring=scorer,            # maximize PR-AUC
    cv=3,                      # 3-fold cross validation
    n_jobs=-1,                 # use all processors
    random_state=1
)

# %%
# Fit the search
random_search.fit(X_train_OH, y_train_)
best_xgb = random_search.best_estimator_

# %%
y_proba_xgb_best = best_xgb.predict_proba(X_test_OH)[:, 1]
y_pred_xgb_best = (y_proba_xgb_best >= 0.5).astype(int)

# 2) Metrics
rec = recall_score(y_test_, y_pred_xgb_best)
prec = precision_score(y_test_, y_pred_xgb_best)
f1 = f1_score(y_test_, y_pred_xgb_best)
pr_auc = average_precision_score(y_test_, y_proba_xgb_best)

print("Tuned XGBoost performance :\n")
print(f"Recall   : {rec:.3f}")
print(f"Precision: {prec:.3f}")
print(f"F1-score : {f1:.3f}")
print(f"PR-AUC   : {pr_auc:.3f}")
# Out:
# Tuned XGBoost performance :
#
# Recall   : 0.728
# Precision: 0.597
# F1-score : 0.656
# PR-AUC   : 0.728

# %% [markdown]
# After tuning, the XGBoost model performs a bit better.

# %%
from sklearn.metrics import precision_recall_curve

# %%
# Compute PR curve
precision, recall, thresholds = precision_recall_curve(y_test_, y_proba_xgb_best)

# Put everything into a dataframe
pr_df = pd.DataFrame({
    "recall": recall,
    "precision": precision
})

# Plot
plt.figure(figsize=(8,6))
sns.lineplot(data=pr_df, x="recall", y="precision", linewidth=2)

plt.title(f"Precision–Recall Curve (XGBoost tuned)\nPR-AUC = {pr_auc:.3f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.grid(True)

plt.show()

# %%
# Function to remove pipeline prefixes like "num_pipe__" or "cat_pipe__"
def clean_feature_name(name):
    name = name.replace("num_pipe__", "")
    name = name.replace("cat_pipe__", "")

    # Replace underscores with spaces for prettier labels
    name = name.replace("_", " ")

    return name

# %%
booster = best_xgb.get_booster()
score_gain = booster.get_score(importance_type="gain")

# Convert to dataframe
fi_gain_df = pd.DataFrame(
    list(score_gain.items()),
    columns=["feature", "importance"]
).sort_values("importance", ascending=False)

top_n = 20
fi_gain_top = fi_gain_df.head(top_n)

fi_gain_top.loc[:,["clean_feature"]] = fi_gain_top["feature"].apply(clean_feature_name)

# %%
# Plotting importance by gain

plt.figure(figsize=(10, 8))
sns.barplot(
    data=fi_gain_top,
    x="importance",
    y="clean_feature"
)
plt.title("Top feature importances by gain (XGBoost tuned)")
plt.xlabel("Gain")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# - Distance to roads and slope stand out as the strongest predictors, suggesting that terrain characteristics greatly influence ignition point probability.
#
# - Meteorological variables such as relative humidity and maximum temperature also play a significant role, which aligns with the physical drivers of fire ignition.
#
# Overall, the model relies on a combination environmental, and climatic factors to detect ignition points.
